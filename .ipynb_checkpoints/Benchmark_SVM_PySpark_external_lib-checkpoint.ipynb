# %% [markdown]
# # **Semiparametric SVM training using subgradients in Spark **
#
# #### bla, bla, bla.
#
# #### We will benchmark the algorithms with data files from UCI:
#
# * **Ripley**, the Ripley dataset
# * **Kwok**, the Kwok dataset
# * **Twonorm**, the Twonorm dataset
# * **Waveform**, the Waveform dataset
# * **Covertype**, the Covertype dataset

# %%
# definir variable de usuario y ejecutar condicionalmente cualquier código que dependa del contexto de ejecución
# no borrar código, simplemente ejecutarlo o no con un "if"
# cada uno mantiene actualizada su parte del "if" y no toca la del otro

user = 'navia'
#user = 'roberto'

#modelo = 'hybrid' 
#modelo = 'kernelgrad' 
overwrite_results = False # overwrites results even when the result file exists, skips the execution otherwise

if user == 'roberto':
    # definir sc
    import findspark
    findspark.init()
    from pyspark import SparkConf, SparkContext
    conf = (SparkConf().setMaster("local[4]").setAppName("My app").set("spark.executor.memory", "2g"))
    sc = SparkContext(conf = conf)
    import common.lib.svm_utils as SVM_UTILS
    import common.lib.quadtree_utils as QUADTREE
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    import pickle
    from math import sqrt
    # %matplotlib inline
    # Se importan las funciones
    from common.lib.SGMAUtils import SGMA
    from common.lib.IRWLSUtils import IRWLS
    from common.lib.ResultsUtils import show_results
    Npartitions = 12
    Samplefraction = 0.05

if user == 'navia':
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/svm_utils.py")
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/IRWLSUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/KernelUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/ResultsUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/SGMAUtils.py")   
    import svm_utils as SVM_UTILS
    #from SGMAUtils import SGMA
    from IRWLSUtils import loadFile, train_SGMA_IRWLS
    #from ResultsUtils import compute_AUCs
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    import pickle
    from math import sqrt
    # %matplotlib inline
    Npartitions = 32
    Samplefraction = 0.05

# 0 = Ripley
# 1 = Kwok
# 2 = Twonorm
# 3 = Waveform
# 4 = Adult

datasets = [0, 1, 2, 3, 4]
folds = [0, 1, 2, 3, 4]
dataset_names = ['Ripley', 'Kwok', 'Twonorm', 'Waveform', 'Adult']
Niters = [50, 100, 200]
NCs = [5, 10, 25, 50, 100, 200]
modelos = ['hybrid', 'kernelgrad', 'SGMA_IRWLS', 'LinearSVM']

datasets = [4]
folds = [0]
modelos = ['LinearSVM']
Niters = [150]
NCs = [20]

for modelo in modelos:
    for kdataset in datasets:
        for kfold in folds:
            for Niter in Niters:
                C = 100.0
                
                if kdataset in [0, 1, 2, 3]: # loading from .mat
                    x_tr, y_tr, x_val, y_val, x_tst, y_tst = SVM_UTILS.load_data(kdataset, kfold)
                    name_dataset = dataset_names[kdataset]
                    NI = x_tr.shape[1]
                    sigma = sqrt(NI)
                    XtrRDD = sc.parallelize(np.hstack((y_tr, x_tr)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                    XvalRDD = sc.parallelize(np.hstack((y_val, x_val)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                    XtstRDD = sc.parallelize(np.hstack((y_tst, x_tst)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                    #XtrRDD.cache()
                    #XvalRDD.cache()
                    #XtstRDD.cache()               

                if kdataset in [4]: # loading libsvm format
                    if kdataset == 4:
                        dimensions = 123
                        
                    name_dataset = dataset_names[kdataset]
                    print "Loading " + name_dataset
                    XtrRDD = loadFile('./data/' + name_dataset.lower() + '_train',sc,dimensions,Npartitions)
                    XvalRDD = loadFile('./data/' + name_dataset.lower() + '_val',sc,dimensions,Npartitions)
                    XtstRDD = loadFile('./data/' + name_dataset.lower() + '_test',sc,dimensions,Npartitions)
                    #print XtrRDD.count(), XvalRDD.count(), XtstRDD.count(), 
                    #XtrRDD.cache()
                    #XvalRDD.cache()
                    #XtstRDD.cache()
                    sigma = np.sqrt(dimensions)
                    

                for NC in NCs:
                    print "Dataset = %s, modelo = %s, kfold = %d, Niter = %d, NC = %d" % (name_dataset, modelo, kfold, Niter, NC)
                    filename = './results/dataset_' + str(kdataset) + '_modelo_' + modelo + '_NC_' + str(NC) + '_Niter_' + str(Niter) + '_kfold_' + str(kfold) + '.pkl'
                    #import code
                    #code.interact(local=locals())
                    try:
                        f = open(filename,'r')
                        f.close()
                        file_exists = True
                    except:
                        file_exists = False
                        pass
                    execute = False
                    if file_exists:
                        if overwrite_results:
                            execute = True
                    else:
                        execute = True                                  
                    if execute:

                        if modelo == 'hybrid':
                            auc_val, auc_tst, exe_time = SVM_UTILS.train_hybridSVM(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, name_dataset, Niter, Samplefraction)

                        if modelo == 'kernelgrad':
                            auc_val, auc_tst, exe_time = SVM_UTILS.train_kernelgrad(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, name_dataset, Niter, Samplefraction)

                        if modelo == 'SGMA_IRWLS':
                            auc_val, auc_tst, exe_time = train_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, name_dataset, Niter, Samplefraction)

                        if modelo == 'linear_SVM':
                            auc_val, auc_tst, exe_time = SVM_UTILS.train_linear_SVM(XtrRDD, XvalRDD, XtstRDD, sigma, C, name_dataset)
                                                
                        with open(filename, 'w') as f:
                            pickle.dump([auc_val, auc_tst, exe_time], f)
# Out:
# Loading Adult
# Dataset = Adult, modelo = SGMA_IRWLS, kfold = 0, Niter = 150, NC = 20
# Centroid 1 : Taking candidates, Evaluating ED, Max ED: 810.30618213 , Updating Matrices Time 12.3100180626
# Centroid 2 : Taking candidates, Evaluating ED, Max ED: 3.77592920013 , Updating Matrices Time 14.2862269878
# Centroid 3 : Taking candidates, Evaluating ED, Max ED: 1.90217201687 , Updating Matrices Time 8.01315593719
# Centroid 4 : Taking candidates, Evaluating ED, Max ED: 0.330451901392 , Updating Matrices Time 5.87016606331
# Centroid 5 : Taking candidates, Evaluating ED, Max ED: 0.293409626471 , Updating Matrices Time 5.43958806992
# Centroid 6 : Taking candidates, Evaluating ED, Max ED: 0.402372453047 , Updating Matrices Time 5.72266197205
# Centroid 7 : Taking candidates, Evaluating ED, Max ED: 0.259140055387 , Updating Matrices Time 6.5184879303
# Centroid 8 : Taking candidates, Evaluating ED, Max ED: 0.303625789823 , Updating Matrices Time 7.90383195877
# Centroid 9 : Taking candidates, Evaluating ED, Max ED: 0.129251931183 , Updating Matrices Time 5.5177218914
# Centroid 10 : Taking candidates, Evaluating ED, Max ED: 0.176485589394 , Updating Matrices Time 6.51235699654
# Centroid 11 : Taking candidates, Evaluating ED, Max ED: 0.229317628968 , Updating Matrices Time 6.17400407791
# Centroid 12 : Taking candidates, Evaluating ED, Max ED: 0.173640115955 , Updating Matrices Time 5.827491045
# Centroid 13 : Taking candidates, Evaluating ED, Max ED: 0.304497829213 , Updating Matrices Time 6.23142004013
# Centroid 14 : Taking candidates, Evaluating ED,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f3192c91619d> in <module>()
#     129
#     130                         if modelo == 'SGMA_IRWLS':
# --> 131                             auc_val, auc_tst, exe_time = train_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, name_dataset, Niter, Samplefraction)
#     132
#     133                         with open(filename, 'w') as f:
#
# /export/workdir/spark/tmp/spark-0736ea99-a69b-4c50-989f-b03e886a34e6/userFiles-f9f126ca-bacf-475c-9859-d182198ae49d/IRWLSUtils.py in train_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, name_dataset, Niter, Samplefraction)
#     129     samplingRate=min(1.0,1000.0/datasetSize)
#     130
# --> 131     Bases = SGMA(XtrRDD,NC,gamma,samplingRate)
#     132
#     133     Pesos = IRWLS(XtrRDD,Bases,C,gamma)
#
# /export/workdir/spark/tmp/spark-0736ea99-a69b-4c50-989f-b03e886a34e6/userFiles-f9f126ca-bacf-475c-9859-d182198ae49d/SGMAUtils.py in SGMA(originaldataset, numCentros, gamma, samplingRate)
#      92
#      93             # Cluster variables
# ---> 94             Descenso =  dataset.map(lambda x:_errorDecrease(x[0],x[1],candidates,gamma,zetalist,samplingRate)).reduce(lambda a,b:a+b)
#      95
#      96             for i in range(len(etalist)):
#
# /opt/spark-1.6.0-bin-2.6.0/python/pyspark/rdd.py in reduce(self, f)
#     795             yield reduce(f, iterator, initial)
#     796
# --> 797         vals = self.mapPartitions(func).collect()
#     798         if vals:
#     799             return reduce(f, vals)
#
# /opt/spark-1.6.0-bin-2.6.0/python/pyspark/rdd.py in collect(self)
#     769         """
#     770         with SCCallSiteSync(self.context) as css:
# --> 771             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     772         return list(_load_from_socket(port, self._jrdd_deserializer))
#     773
#
# /opt/spark-1.6.0-bin-2.6.0/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     809             proto.END_COMMAND_PART
#     810
# --> 811         answer = self.gateway_client.send_command(command)
#     812         return_value = get_return_value(
#     813             answer, self.gateway_client, self.target_id, self.name)
#
# /opt/spark-1.6.0-bin-2.6.0/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in send_command(self, command, retry)
#     624         connection = self._get_connection()
#     625         try:
# --> 626             response = connection.send_command(command)
#     627             self._give_back_connection(connection)
#     628         except Py4JNetworkError:
#
# /opt/spark-1.6.0-bin-2.6.0/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in send_command(self, command)
#     738         try:
#     739             self.socket.sendall(command.encode("utf-8"))
# --> 740             answer = smart_decode(self.stream.readline()[:-1])
#     741             logger.debug("Answer received: {0}".format(answer))
#     742             # Happens when a the other end is dead. There might be an empty
#
# /usr/lib64/python2.7/socket.pyc in readline(self, size)
#     432                     try:
#     433                         while data != "\n":
# --> 434                             data = recv(1)
#     435                             if not data:
#     436                                 break
#
# KeyboardInterrupt:
