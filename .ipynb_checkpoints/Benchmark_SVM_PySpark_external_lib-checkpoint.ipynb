# %% [markdown]
# # **Semiparametric SVM training using subgradients in Spark **
#
# #### bla, bla, bla.
#
# #### We will benchmark the algorithms with data files from UCI:
#
# * **Ripley**, the Ripley dataset
# * **Kwok**, the Kwok dataset
# * **Twonorm**, the Twonorm dataset
# * **Waveform**, the Waveform dataset
# * **Covertype**, the Covertype dataset

# %%
# definir variable de usuario y ejecutar condicionalmente cualquier código que dependa del contexto de ejecución
# no borrar código, simplemente ejecutarlo o no con un "if"
# cada uno mantiene actualizada su parte del "if" y no toca la del otro

#user = 'navia'
user = 'roberto'

#modelo = 'hybrid' 
#modelo = 'kernelgrad' 
overwrite_results = True # overwrites results even when the result file exists, skips the execution otherwise

if user == 'roberto':
    # definir sc
    import findspark
    findspark.init()
    from pyspark import SparkConf, SparkContext
    conf = (SparkConf().setMaster("local[4]").setAppName("My app").set("spark.executor.memory", "2g"))
    sc = SparkContext(conf = conf)
    import common.lib.svm_utils as SVM_UTILS
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    import pickle
    from pyspark.mllib.linalg import SparseVector, DenseVector
    from math import sqrt
    # %matplotlib inline
    # Se importan las funciones
    from pyspark.mllib.util import MLUtils
    from common.lib.IRWLSUtils import *
    Npartitions = 12
    Samplefraction = 0.05

if user == 'navia':
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/svm_utils.py")
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/IRWLSUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/KernelUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/ResultsUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/SGMAUtils.py")   
    import svm_utils as SVM_UTILS
    #from SGMAUtils import SGMA
    from IRWLSUtils import loadFile, train_SGMA_IRWLS, train_random_IRWLS, train_hybrid_SGMA_IRWLS, train_kmeans_IRWLS
    #from ResultsUtils import compute_AUCs
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    from pyspark.mllib.linalg import SparseVector, DenseVector
    import pickle
    from math import sqrt
    from pyspark.mllib.util import MLUtils
    # %matplotlib inline
    Npartitions = -99 # cuando es menor que 0, no se aplica y se deja libre
    Samplefraction = 0.05

# 0 = Ripley
# 1 = Kwok
# 2 = Twonorm
# 3 = Waveform
# 4 = Adult
# 5 = SUSY
# 6 = KddCup1999, requiere preprocesado...
# 7 = Higgs

datasets = [0, 1, 2, 3, 4, 5, 6]
folds = [0, 1, 2, 3, 4]
dataset_names = ['Ripley', 'Kwok', 'Twonorm', 'Waveform', 'Adult', 'Susy', 'KddCup1999', 'Higgs']
Niters = [50, 100, 200]
NCs = [5, 10, 25, 50, 100, 200]
modelos = ['hybridgrad', 'kernelgrad', 'SGMA_IRWLS', 'LinearSVM', 'Logistic', 'random_IRWLS', 'hybrid_IRWLS', 'Kmeans_IRWLS']

datasets = [4]
folds = [0]
modelos = ['SGMA_IRWLS']
Niters = [300]
NCs = [50]
Samplefraction = 0.05
IRWLS_stop_criteria=1e-3

for modelo in modelos:
    for kdataset in datasets:
        for kfold in folds:
            for Niter in Niters:
                C = 100.0
                name_dataset = dataset_names[kdataset]
                
                #####################################################################################################################
                # DATA LOADING: the result of this part must always be three RDDs for train, val and test, containing labelled points.
                #####################################################################################################################
                if kdataset in [0, 1, 2, 3]: # loading from .mat
                    x_tr, y_tr, x_val, y_val, x_tst, y_tst = SVM_UTILS.load_data(kdataset, kfold)
                    NI = x_tr.shape[1]
                    sigma = sqrt(NI)
                    
                    if Npartitions > 0:
                        XtrRDD = sc.parallelize(np.hstack((y_tr, x_tr)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XvalRDD = sc.parallelize(np.hstack((y_val, x_val)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XtstRDD = sc.parallelize(np.hstack((y_tst, x_tst)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                    else:
                        XtrRDD = sc.parallelize(np.hstack((y_tr, x_tr))).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XvalRDD = sc.parallelize(np.hstack((y_val, x_val))).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XtstRDD = sc.parallelize(np.hstack((y_tst, x_tst))).map(lambda x: LabeledPoint(x[0], x[1:]))
                       
                        
                if kdataset in [4]: # loading libsvm format
                    if kdataset == 4:
                        dimensions = 123                       
                    print "Loading " + name_dataset
                    XtrRDD = loadFile('./data/' + name_dataset.lower() + '_train',sc,dimensions,Npartitions)
                    XvalRDD = loadFile('./data/' + name_dataset.lower() + '_val',sc,dimensions,Npartitions)
                    XtstRDD = loadFile('./data/' + name_dataset.lower() + '_test',sc,dimensions,Npartitions)
                    sigma = np.sqrt(dimensions)
                    
                if kdataset in [5]: # loading in libsvm format and splitting RDD
                    if kdataset == 5:
                        filename = 'file:///export/usuarios01/navia/spark/SVM_spark/data/SUSY.txt'
                        if user == 'roberto':
                            filename = 'file:///home/operador/Documentos/AngelBigDataSVM/SVM_spark/data/SUSY.txt'
                        #filename = 'file:///export/usuarios01/navia/spark/SVM_spark/data/minisusy.txt'
                        dimensions = 18
                    rawdata = MLUtils.loadLibSVMFile(sc, filename)
                    # Labelled points are sparse, we map the values
                    rawdata = rawdata.map(lambda x: LabeledPoint(x.label, DenseVector((x.features).toArray())  ))
                    XtrRDD, XvalRDD, XtstRDD = rawdata.randomSplit(weights=[0.7, 0.1, 0.2], seed=1234)
                    sigma = np.sqrt(dimensions)               
                    XtrRDD.cache()
                    XvalRDD.cache()
                    XtstRDD.cache()
                #################################   END LOADING DATA ##########################################################
                
                for NC in NCs:
                    print "Dataset = %s, modelo = %s, kfold = %d, Niter = %d, NC = %d" % (name_dataset, modelo, kfold, Niter, NC)
                    filename = './results/dataset_' + str(kdataset) + '_modelo_' + modelo + '_NC_' + str(NC) + '_Niter_' + str(Niter) + '_kfold_' + str(kfold) + '.pkl'
                    #import code
                    #code.interact(local=locals())
                    try:
                        f = open(filename,'r')
                        f.close()
                        file_exists = True
                    except:
                        file_exists = False
                        pass
                    execute = False
                    if file_exists:
                        if overwrite_results:
                            execute = True
                    else:
                        execute = True                                  
                    if execute:

                        if modelo == 'hybridgrad':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_hybridSVM(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, Samplefraction)

                        if modelo == 'kernelgrad':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_kernelgrad(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, Samplefraction)

                        if modelo == 'SGMA_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_SGMA_IRWLS_ByKey(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria=IRWLS_stop_criteria)

                        if modelo == 'LinearSVM':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_linear_SVM(XtrRDD, XvalRDD, XtstRDD)
                                                
                        if modelo == 'Logistic':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_logistic(XtrRDD, XvalRDD, XtstRDD)

                        if modelo == 'random_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_random_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria=IRWLS_stop_criteria)

                        if modelo == 'hybrid_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_hybrid_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria=IRWLS_stop_criteria)

                        if modelo == 'Kmeans_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_kmeans_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria=IRWLS_stop_criteria)

                        print "Dataset = %s, modelo = %s, kfold = %d, Niter = %d, NC = %d" % (name_dataset, modelo, kfold, Niter, NC)
                        print "AUCtr = %f, AUCval = %f, AUCtst = %f" % (auc_tr, auc_val, auc_tst)
                        print "Elapsed minutes = %f" % (exe_time / 60.0)

                        with open(filename, 'w') as f:
                            pickle.dump([auc_tr, auc_val, auc_tst, exe_time], f)
# Out:
# Loading Adult
# Dataset = Adult, modelo = SGMA_IRWLS, kfold = 0, Niter = 300, NC = 50
# Centroid 1 : Taking candidates, Evaluating ED, Max ED: 867.381756855 , Updating Matrices Time 1.33151078224
# Centroid 2 : Taking candidates, Evaluating ED, Max ED: 3.65382500423 , Updating Matrices Time 2.5634560585
# Centroid 3 : Taking candidates, Evaluating ED, Max ED: 0.96646807855 , Updating Matrices Time 1.88295006752
# Centroid 4 : Taking candidates, Evaluating ED, Max ED: 0.207261465601 , Updating Matrices Time 2.03023099899
# Centroid 5 : Taking candidates, Evaluating ED, Max ED: 0.154891811945 , Updating Matrices Time 2.22567605972
# Centroid 6 : Taking candidates, Evaluating ED, Max ED: 0.132074205057 , Updating Matrices Time 1.95504593849
# Centroid 7 : Taking candidates, Evaluating ED, Max ED: 0.111498739248 , Updating Matrices Time 2.105645895
# Centroid 8 : Taking candidates, Evaluating ED, Max ED: 0.0699942710101 , Updating Matrices Time 1.83720397949
# Centroid 9 : Taking candidates, Evaluating ED, Max ED: 0.0486944698592 , Updating Matrices Time 2.27350378036
# Centroid 10 : Taking candidates, Evaluating ED, Max ED: 0.0520222799094 , Updating Matrices Time 1.96125912666
# Centroid 11 : Taking candidates, Evaluating ED, Max ED: 0.0617102562289 , Updating Matrices Time 1.82590103149
# Centroid 12 : Taking candidates, Evaluating ED, Max ED: 0.0483095263825 , Updating Matrices Time 2.24469184875
# Centroid 13 : Taking candidates, Evaluating ED, Max ED: 0.0381851600676 , Updating Matrices Time 2.14477109909
# Centroid 14 : Taking candidates, Evaluating ED, Max ED: 0.0431089661073 , Updating Matrices Time 2.10498905182
# Centroid 15 : Taking candidates, Evaluating ED, Max ED: 0.0257730094932 , Updating Matrices Time 2.2247800827
# Centroid 16 : Taking candidates, Evaluating ED, Max ED: 0.0432638789145 , Updating Matrices Time 2.30540180206
# Centroid 17 : Taking candidates, Evaluating ED, Max ED: 0.0394526961029 , Updating Matrices Time 2.3211619854
# Centroid 18 : Taking candidates, Evaluating ED, Max ED: 0.0281954958038 , Updating Matrices Time 2.11999607086
# Centroid 19 : Taking candidates, Evaluating ED, Max ED: 0.0213382595781 , Updating Matrices Time 2.29610204697
# Centroid 20 : Taking candidates, Evaluating ED, Max ED: 0.0353523965787 , Updating Matrices Time 1.78299188614
# Centroid 21 : Taking candidates, Evaluating ED, Max ED: 0.0193367781932 , Updating Matrices Time 2.10477089882
# Centroid 22 : Taking candidates, Evaluating ED, Max ED: 0.0216864544214 , Updating Matrices Time 1.73963403702
# Centroid 23 : Taking candidates, Evaluating ED, Max ED: 0.0218023175941 , Updating Matrices Time 2.21355319023
# Centroid 24 : Taking candidates, Evaluating ED, Max ED: 0.0121466136424 , Updating Matrices Time 2.39117479324
# Centroid 25 : Taking candidates, Evaluating ED, Max ED: 0.0103346819913 , Updating Matrices Time 1.86225914955
# Centroid 26 : Taking candidates, Evaluating ED, Max ED: 0.010684964578 , Updating Matrices Time 1.84587192535
# Centroid 27 : Taking candidates, Evaluating ED, Max ED: 0.00686496214183 , Updating Matrices Time 2.03271794319
# Centroid 28 : Taking candidates, Evaluating ED, Max ED: 0.0108341000288 , Updating Matrices Time 2.29572296143
# Centroid 29 : Taking candidates, Evaluating ED, Max ED: 0.00725504757413 , Updating Matrices Time 1.74162197113
# Centroid 30 : Taking candidates, Evaluating ED, Max ED: 0.0074033565799 , Updating Matrices Time 1.79825210571
# Centroid 31 : Taking candidates, Evaluating ED, Max ED: 0.00641799170112 , Updating Matrices Time 1.87825512886
# Centroid 32 : Taking candidates, Evaluating ED, Max ED: 0.00713423522793 , Updating Matrices Time 2.24597811699
# Centroid 33 : Taking candidates, Evaluating ED, Max ED: 0.0076319543526 , Updating Matrices Time 1.96888399124
# Centroid 34 : Taking candidates, Evaluating ED, Max ED: 0.00780569130468 , Updating Matrices Time 2.17783808708
# Centroid 35 : Taking candidates, Evaluating ED, Max ED: 0.00689189335875 , Updating Matrices Time 2.11303710938
# Centroid 36 : Taking candidates, Evaluating ED, Max ED: 0.0060627557072 , Updating Matrices Time 1.91526794434
# Centroid 37 : Taking candidates, Evaluating ED, Max ED: 0.00433618886386 , Updating Matrices Time 2.34893012047
# Centroid 38 : Taking candidates, Evaluating ED, Max ED: 0.00743874142404 , Updating Matrices Time 2.19012904167
# Centroid 39 : Taking candidates, Evaluating ED, Max ED: 0.00459613886439 , Updating Matrices Time 2.35241413116
# Centroid 40 : Taking candidates, Evaluating ED, Max ED: 0.00392211227378 , Updating Matrices Time 2.20175504684
# Centroid 41 : Taking candidates, Evaluating ED, Max ED: 0.00292348173022 , Updating Matrices Time 1.81589913368
# Centroid 42 : Taking candidates, Evaluating ED, Max ED: 0.00350295314763 , Updating Matrices Time 1.89351701736
# Centroid 43 : Taking candidates, Evaluating ED, Max ED: 0.00174398913902 , Updating Matrices Time 1.87453007698
# Centroid 44 : Taking candidates, Evaluating ED, Max ED: 0.00291316050519 , Updating Matrices Time 1.83935379982
# Centroid 45 : Taking candidates, Evaluating ED, Max ED: 0.00210127237766 , Updating Matrices Time 1.85713601112
# Centroid 46 : Taking candidates, Evaluating ED, Max ED: 0.00421251874611 , Updating Matrices Time 2.34867620468
# Centroid 47 : Taking candidates, Evaluating ED, Max ED: 0.00191684437196 , Updating Matrices Time 2.19461798668
# Centroid 48 : Taking candidates, Evaluating ED, Max ED: 0.00210664455656 , Updating Matrices Time 2.31536006927
# Centroid 49 : Taking candidates, Evaluating ED, Max ED: 0.00172855550543 , Updating Matrices Time 2.04368710518
# Centroid 50 : Taking candidates, Evaluating ED, Max ED: 0.00193459818194 , Updating Matrices Time 2.31422185898
# Iteration 1 : DeltaW/W inf , Iteration Time 0.567372083664
# Iteration 2 : DeltaW/W 0.280976180524 , Iteration Time 0.533380031586
# Iteration 3 : DeltaW/W 0.15507948805 , Iteration Time 0.382694959641
# Iteration 4 : DeltaW/W 0.120584078703 , Iteration Time 0.536999940872
# Iteration 5 : DeltaW/W 0.0918569407503 , Iteration Time 0.392784833908
# Iteration 6 : DeltaW/W 0.130918324454 , Iteration Time 0.352380037308
# Iteration 7 : DeltaW/W 0.108645435022 , Iteration Time 0.431743860245
# Iteration 8 : DeltaW/W 0.0764185573812 , Iteration Time 0.366152048111
# Iteration 9 : DeltaW/W 0.0719369297747 , Iteration Time 0.351541996002
# Iteration 10 : DeltaW/W 0.0862740891788 , Iteration Time 0.461573123932
# Iteration 11 : DeltaW/W 0.0944257111538 , Iteration Time 0.461395978928
# Iteration 12 : DeltaW/W 0.0601099554016 , Iteration Time 0.486880064011
# Iteration 13 : DeltaW/W 0.0551693814011 , Iteration Time 0.454671859741
# Iteration 14 : DeltaW/W 0.0391064917862 , Iteration Time 0.445080041885
# Iteration 15 : DeltaW/W 0.0408261548093 , Iteration Time 0.46089720726
# Iteration 16 : DeltaW/W 0.0342195844056 , Iteration Time 0.482095003128
# Iteration 17 : DeltaW/W 0.0377970619613 , Iteration Time 0.452764034271
# Iteration 18 : DeltaW/W 0.0251329551068 , Iteration Time 0.335657835007
# Iteration 19 : DeltaW/W 0.0193365513351 , Iteration Time 0.450115919113
# Iteration 20 : DeltaW/W 0.0147314051908 , Iteration Time 0.326271057129
# Iteration 21 : DeltaW/W 0.0126427041048 , Iteration Time 0.463948011398
# Iteration 22 : DeltaW/W 0.00993415702419 , Iteration Time 0.336035013199
# Iteration 23 : DeltaW/W 0.00858917799033 , Iteration Time 0.461309909821
# Iteration 24 : DeltaW/W 0.0073072186049 , Iteration Time 0.31930398941
# Iteration 25 : DeltaW/W 0.00617546389731 , Iteration Time 0.35015296936
# Iteration 26 : DeltaW/W 0.00508516066306 , Iteration Time 0.473523139954
# Iteration 27 : DeltaW/W 0.00423878738517 , Iteration Time 0.447633981705
# Iteration 28 : DeltaW/W 0.00365277129161 , Iteration Time 0.317929983139
# Iteration 29 : DeltaW/W 0.00323915071177 , Iteration Time 0.334753036499
# Iteration 30 : DeltaW/W 0.00299831375289 , Iteration Time 0.468334913254
# Iteration 31 : DeltaW/W 0.00253646938743 , Iteration Time 0.470442056656
# Iteration 32 : DeltaW/W 0.00205488263321 , Iteration Time 0.337481975555
# Iteration 33 : DeltaW/W 0.00172831392843 , Iteration Time 0.329482793808
# Iteration 34 : DeltaW/W 0.00148881334647 , Iteration Time 0.475258111954
# Iteration 35 : DeltaW/W 0.00135949248019 , Iteration Time 0.327964067459
# Iteration 36 : DeltaW/W 0.00125101384799 , Iteration Time 0.417892932892
# Iteration 37 : DeltaW/W 0.00114324869753 , Iteration Time 0.44924902916
# Iteration 38 : DeltaW/W 0.0010351007487 , Iteration Time 0.453639030457
# Dataset = Adult, modelo = SGMA_IRWLS, kfold = 0, Niter = 300, NC = 50
# AUCtr = 0.901001, AUCval = 0.899967, AUCtst = 0.901001
# Elapsed minutes = 2.673761
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-5f88b701aef5> in <module>()
#     173                         print "Elapsed minutes = %f" % (exe_time / 60.0)
#     174
# --> 175                         with open(filename, 'w') as f:
#     176                             pickle.dump([auc_tr, auc_val, auc_tst, exe_time], f)
#
# IOError: [Errno 2] No such file or directory: './results/dataset_4_modelo_SGMA_IRWLS_NC_50_Niter_300_kfold_0.pkl'
