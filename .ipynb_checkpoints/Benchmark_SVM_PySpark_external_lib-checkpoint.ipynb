# %% [markdown]
# # **Semiparametric SVM training using subgradients in Spark **
#
# #### bla, bla, bla.
#
# #### We will benchmark the algorithms with data files from UCI:
#
# * **Ripley**, the Ripley dataset
# * **Kwok**, the Kwok dataset
# * **Twonorm**, the Twonorm dataset
# * **Waveform**, the Waveform dataset
# * **Covertype**, the Covertype dataset

# %%
# definir variable de usuario y ejecutar condicionalmente cualquier código que dependa del contexto de ejecución
# no borrar código, simplemente ejecutarlo o no con un "if"
# cada uno mantiene actualizada su parte del "if" y no toca la del otro

user = 'navia'
#user = 'roberto'

#modelo = 'hybrid' 
#modelo = 'kernelgrad' 
overwrite_results = True # overwrites results even when the result file exists, skips the execution otherwise

if user == 'roberto':
    # definir sc
    import findspark
    findspark.init()
    from pyspark import SparkConf, SparkContext
    conf = (SparkConf().setMaster("local[4]").setAppName("My app").set("spark.executor.memory", "2g"))
    sc = SparkContext(conf = conf)
    import common.lib.svm_utils as SVM_UTILS
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    import pickle
    from math import sqrt
    # %matplotlib inline
    # Se importan las funciones
    from pyspark.mllib.util import MLUtils
    from common.lib.IRWLSUtils import *
    Npartitions = 12
    Samplefraction = 0.05

if user == 'navia':
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/svm_utils.py")
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/IRWLSUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/KernelUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/ResultsUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/SGMAUtils.py")   
    import svm_utils as SVM_UTILS
    #from SGMAUtils import SGMA
    from IRWLSUtils import loadFile, train_SGMA_IRWLS, train_random_IRWLS, train_hybrid_SGMA_IRWLS, train_kmeans_IRWLS
    #from ResultsUtils import compute_AUCs
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    from pyspark.mllib.linalg import SparseVector, DenseVector
    import pickle
    from math import sqrt
    from pyspark.mllib.util import MLUtils
    # %matplotlib inline
    Npartitions = -99 # cuando es menor que 0, no se aplica y se deja libre
    Samplefraction = 0.05

# 0 = Ripley
# 1 = Kwok
# 2 = Twonorm
# 3 = Waveform
# 4 = Adult
# 5 = SUSY
# 6 = KddCup1999

datasets = [0, 1, 2, 3, 4, 5, 6]
folds = [0, 1, 2, 3, 4]
dataset_names = ['Ripley', 'Kwok', 'Twonorm', 'Waveform', 'Adult', 'Susy', 'KddCup1999']
Niters = [50, 100, 200]
NCs = [5, 10, 25, 50, 100, 200]
modelos = ['hybridgrad', 'kernelgrad', 'SGMA_IRWLS', 'LinearSVM', 'Logistic', 'random_IRWLS', 'hybrid_IRWLS', 'Kmeans_IRWLS']

datasets = [4]
folds = [0]
modelos = ['hybridgrad']
Niters = [300]
NCs = [20]
Samplefraction = 0.05

for modelo in modelos:
    for kdataset in datasets:
        for kfold in folds:
            for Niter in Niters:
                C = 100.0
                name_dataset = dataset_names[kdataset]
                
                #####################################################################################################################
                # DATA LOADING: the result of this part must always be three RDDs for train, val and test, containing labelled points.
                #####################################################################################################################
                if kdataset in [0, 1, 2, 3]: # loading from .mat
                    x_tr, y_tr, x_val, y_val, x_tst, y_tst = SVM_UTILS.load_data(kdataset, kfold)
                    NI = x_tr.shape[1]
                    sigma = sqrt(NI)
                    
                    if Npartitions > 0:
                        XtrRDD = sc.parallelize(np.hstack((y_tr, x_tr)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XvalRDD = sc.parallelize(np.hstack((y_val, x_val)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XtstRDD = sc.parallelize(np.hstack((y_tst, x_tst)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                    else:
                        XtrRDD = sc.parallelize(np.hstack((y_tr, x_tr))).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XvalRDD = sc.parallelize(np.hstack((y_val, x_val))).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XtstRDD = sc.parallelize(np.hstack((y_tst, x_tst))).map(lambda x: LabeledPoint(x[0], x[1:]))
                       
                        
                if kdataset in [4]: # loading libsvm format
                    if kdataset == 4:
                        dimensions = 123                       
                    print "Loading " + name_dataset
                    XtrRDD = loadFile('./data/' + name_dataset.lower() + '_train',sc,dimensions,Npartitions)
                    XvalRDD = loadFile('./data/' + name_dataset.lower() + '_val',sc,dimensions,Npartitions)
                    XtstRDD = loadFile('./data/' + name_dataset.lower() + '_test',sc,dimensions,Npartitions)
                    sigma = np.sqrt(dimensions)
                    
                if kdataset in [5]: # loading in libsvm format and splitting RDD
                    if kdataset == 5:
                        filename = 'file:///export/usuarios01/navia/spark/SVM_spark/data/SUSY.txt'
                        #filename = 'file:///export/usuarios01/navia/spark/SVM_spark/data/minisusy.txt'
                        dimensions = 18
                    rawdata = MLUtils.loadLibSVMFile(sc, filename)
                    # Labelled points are sparse, we map the values
                    rawdata = rawdata.map(lambda x: LabeledPoint(x.label, DenseVector((x.features).toArray())  ))
                    XtrRDD, XvalRDD, XtstRDD = rawdata.randomSplit(weights=[0.7, 0.1, 0.2], seed=1234)
                    sigma = np.sqrt(dimensions)
                
                #XtrRDD.cache()
                #XvalRDD.cache()
                #XtstRDD.cache()
                #################################   END LOADING DATA ##########################################################
                
                for NC in NCs:
                    print "Dataset = %s, modelo = %s, kfold = %d, Niter = %d, NC = %d" % (name_dataset, modelo, kfold, Niter, NC)
                    filename = './results/dataset_' + str(kdataset) + '_modelo_' + modelo + '_NC_' + str(NC) + '_Niter_' + str(Niter) + '_kfold_' + str(kfold) + '.pkl'
                    #import code
                    #code.interact(local=locals())
                    try:
                        f = open(filename,'r')
                        f.close()
                        file_exists = True
                    except:
                        file_exists = False
                        pass
                    execute = False
                    if file_exists:
                        if overwrite_results:
                            execute = True
                    else:
                        execute = True                                  
                    if execute:

                        if modelo == 'hybridgrad':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_hybridSVM(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, Samplefraction)

                        if modelo == 'kernelgrad':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_kernelgrad(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, Samplefraction)

                        if modelo == 'SGMA_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter)

                        if modelo == 'LinearSVM':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_linear_SVM(XtrRDD, XvalRDD, XtstRDD)
                                                
                        if modelo == 'Logistic':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_logistic(XtrRDD, XvalRDD, XtstRDD)

                        if modelo == 'random_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_random_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter)

                        if modelo == 'hybrid_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_hybrid_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter)

                        if modelo == 'Kmeans_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_kmeans_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter)

                        print "AUCtr = %f, AUCval = %f, AUCtst = %f" % (auc_tr, auc_val, auc_tst)
                        print "Elapsed minutes = %f" % (exe_time / 60.0)

                        with open(filename, 'w') as f:
                            pickle.dump([auc_tr, auc_val, auc_tst, exe_time], f)
# Out:
# Loading Adult
# Dataset = Adult, modelo = hybrid_IRWLS, kfold = 0, Niter = 150, NC = 100
# Centroid 1 : Taking candidates, Evaluating ED, Max ED: 795.174438873 , Updating Matrices Time 1.15868091583
# Centroid 2 : Taking candidates, Evaluating ED, Max ED: 4.76129257879 , Updating Matrices Time 2.28930306435
# Centroid 3 : Taking candidates, Evaluating ED, Max ED: 0.677234627609 , Updating Matrices Time 2.31951117516
# Centroid 4 : Taking candidates, Evaluating ED, Max ED: 0.473835947939 , Updating Matrices Time 2.38034200668
# Centroid 5 : Taking candidates, Evaluating ED, Max ED: 0.294222636319 , Updating Matrices Time 2.36552286148
# Centroid 6 : Taking candidates, Evaluating ED, Max ED: 0.178039277777 , Updating Matrices Time 2.37462806702
# Centroid 7 : Taking candidates, Evaluating ED, Max ED: 0.223629290955 , Updating Matrices Time 2.34552598
# Centroid 8 : Taking candidates, Evaluating ED, Max ED: 0.301502101141 , Updating Matrices Time 2.37385988235
# Centroid 9 : Taking candidates, Evaluating ED, Max ED: 0.248985009413 , Updating Matrices Time 2.44798398018
# Centroid 10 : Taking candidates, Evaluating ED, Max ED: 0.207781501704 , Updating Matrices Time 2.41700291634
# Centroid 11 : Taking candidates, Evaluating ED, Max ED: 0.220696491467 , Updating Matrices Time 2.41525197029
# Centroid 12 : Taking candidates, Evaluating ED, Max ED: 0.209518959131 , Updating Matrices Time 2.46436619759
# Centroid 13 : Taking candidates, Evaluating ED, Max ED: 0.243675839142 , Updating Matrices Time 2.45239496231
# Centroid 14 : Taking candidates, Evaluating ED, Max ED: 0.238414438678 , Updating Matrices Time 2.47012400627
# Centroid 15 : Taking candidates, Evaluating ED, Max ED: 0.161276948709 , Updating Matrices Time 2.44342303276
# Centroid 16 : Taking candidates, Evaluating ED, Max ED: 0.128805392304 , Updating Matrices Time 2.4635579586
# Centroid 17 : Taking candidates, Evaluating ED, Max ED: 0.209501513455 , Updating Matrices Time 2.5270421505
# Centroid 18 : Taking candidates, Evaluating ED, Max ED: 0.150391527366 , Updating Matrices Time 2.47729611397
# Centroid 19 : Taking candidates, Evaluating ED, Max ED: 0.185977937841 , Updating Matrices Time 2.69383502007
# Centroid 20 : Taking candidates, Evaluating ED, Max ED: 0.21343849179 , Updating Matrices Time 2.72194695473
# Centroid 21 : Taking candidates, Evaluating ED, Max ED: 0.143265490436 , Updating Matrices Time 2.76194310188
# Centroid 22 : Taking candidates, Evaluating ED, Max ED: 0.17627727064 , Updating Matrices Time 2.76366710663
# Centroid 23 : Taking candidates, Evaluating ED, Max ED: 0.159139446783 , Updating Matrices Time 2.78662991524
# Centroid 24 : Taking candidates, Evaluating ED, Max ED: 0.0879935564554 , Updating Matrices Time 2.73342490196
# Centroid 25 : Taking candidates, Evaluating ED, Max ED: 0.114628604495 , Updating Matrices Time 2.7771320343
# Centroid 26 : Taking candidates, Evaluating ED, Max ED: 0.152635579654 , Updating Matrices Time 2.78130793571
# Centroid 27 : Taking candidates, Evaluating ED, Max ED: 0.189742737617 , Updating Matrices Time 2.94124603271
# Centroid 28 : Taking candidates, Evaluating ED, Max ED: 0.13484161649 , Updating Matrices Time 2.79165291786
# Centroid 29 : Taking candidates, Evaluating ED, Max ED: 0.191160758595 , Updating Matrices Time 2.78633999825
# Centroid 30 : Taking candidates, Evaluating ED, Max ED: 0.115552150981 , Updating Matrices Time 2.78932905197
# Centroid 31 : Taking candidates, Evaluating ED, Max ED: 0.106422514838 , Updating Matrices Time 2.7713739872
# Centroid 32 : Taking candidates, Evaluating ED, Max ED: 0.108476750784 , Updating Matrices Time 2.79809212685
# Centroid 33 : Taking candidates, Evaluating ED, Max ED: 0.0883877790988 , Updating Matrices Time 2.85205602646
# Centroid 34 : Taking candidates, Evaluating ED, Max ED: 0.27224820554 , Updating Matrices Time 2.87345600128
# Centroid 35 : Taking candidates, Evaluating ED, Max ED: 0.113531528445 , Updating Matrices Time 2.82438206673
# Centroid 36 : Taking candidates, Evaluating ED, Max ED: 0.159932174626 , Updating Matrices Time 2.85849404335
# Centroid 37 : Taking candidates, Evaluating ED, Max ED: 0.167985594401 , Updating Matrices Time 3.27092909813
# Centroid 38 : Taking candidates, Evaluating ED, Max ED: 0.148897137195 , Updating Matrices Time 2.89008593559
# Centroid 39 : Taking candidates, Evaluating ED, Max ED: 0.191122893026 , Updating Matrices Time 2.85081315041
# Centroid 40 : Taking candidates, Evaluating ED, Max ED: 0.0785370083104 , Updating Matrices Time 3.01438617706
# Centroid 41 : Taking candidates, Evaluating ED, Max ED: 0.0874975939935 , Updating Matrices Time 2.86684203148
# Centroid 42 : Taking candidates, Evaluating ED, Max ED: 0.138972189525 , Updating Matrices Time 2.9206430912
# Centroid 43 : Taking candidates, Evaluating ED, Max ED: 0.109576169911 , Updating Matrices Time 3.13121891022
# Centroid 44 : Taking candidates, Evaluating ED, Max ED: 0.148591360043 , Updating Matrices Time 2.9106388092
# Centroid 45 : Taking candidates, Evaluating ED, Max ED: 0.128653279747 , Updating Matrices Time 2.96750688553
# Centroid 46 : Taking candidates, Evaluating ED, Max ED: 0.121782137203 , Updating Matrices Time 2.97116303444
# Centroid 47 : Taking candidates, Evaluating ED, Max ED: 0.222638526563 , Updating Matrices Time 2.88588190079
# Centroid 48 : Taking candidates, Evaluating ED, Max ED: 0.156374733565 , Updating Matrices Time 2.99244904518
# Centroid 49 : Taking candidates, Evaluating ED, Max ED: 0.0725779809705 , Updating Matrices Time 2.98855781555
# Centroid 50 : Taking candidates, Evaluating ED, Max ED: 0.117912778304 , Updating Matrices Time 3.06169390678
# Centroid 51 : Taking candidates, Evaluating ED, Max ED: 0.0872017330497 , Updating Matrices Time 2.96472501755
# Centroid 52 : Taking candidates, Evaluating ED, Max ED: 0.0744547688383 , Updating Matrices Time 3.09048295021
# Centroid 53 : Taking candidates, Evaluating ED, Max ED: 0.105380604966 , Updating Matrices Time 3.06160593033
# Centroid 54 : Taking candidates, Evaluating ED, Max ED: 0.0908927335001 , Updating Matrices Time 3.02333402634
# Centroid 55 : Taking candidates, Evaluating ED, Max ED: 0.100914153743 , Updating Matrices Time 3.05724596977
# Centroid 56 : Taking candidates, Evaluating ED, Max ED: 0.0887638504274 , Updating Matrices Time 3.03755784035
# Centroid 57 : Taking candidates, Evaluating ED, Max ED: 0.176318397357 , Updating Matrices Time 2.98592400551
# Centroid 58 : Taking candidates, Evaluating ED, Max ED: 0.103294670798 , Updating Matrices Time 3.04921913147
# Centroid 59 : Taking candidates, Evaluating ED, Max ED: 0.100140050624 , Updating Matrices Time 3.15086007118
# Centroid 60 : Taking candidates, Evaluating ED, Max ED: 0.0721170614114 , Updating Matrices Time 3.02703213692
# Centroid 61 : Taking candidates, Evaluating ED, Max ED: 0.0883599614619 , Updating Matrices Time 3.0618519783
# Centroid 62 : Taking candidates, Evaluating ED, Max ED: 0.0545871084666 , Updating Matrices Time 3.06213593483
# Centroid 63 : Taking candidates, Evaluating ED, Max ED: 0.11359218912 , Updating Matrices Time 3.08862519264
# Centroid 64 : Taking candidates, Evaluating ED, Max ED: 0.0937237976649 , Updating Matrices Time 3.0841550827
# Centroid 65 : Taking candidates, Evaluating ED, Max ED: 0.0736141476686 , Updating Matrices Time 3.08009386063
# Centroid 66 : Taking candidates, Evaluating ED, Max ED: 0.0516065272524 , Updating Matrices Time 3.18599200249
# Centroid 67 : Taking candidates, Evaluating ED, Max ED: 0.0946664709591 , Updating Matrices Time 3.04096293449
# Centroid 68 : Taking candidates, Evaluating ED, Max ED: 0.0502570944577 , Updating Matrices Time 3.14151310921
# Centroid 69 : Taking candidates, Evaluating ED, Max ED: 0.051366081141 , Updating Matrices Time 3.0681180954
# Centroid 70 : Taking candidates, Evaluating ED, Max ED: 0.0882210911385 , Updating Matrices Time 3.10335111618
# Centroid 71 : Taking candidates, Evaluating ED, Max ED: 0.0681753979587 , Updating Matrices Time 3.13422513008
# Centroid 72 : Taking candidates, Evaluating ED, Max ED: 0.0695850444064 , Updating Matrices Time 3.12894511223
# Centroid 73 : Taking candidates, Evaluating ED, Max ED: 0.0540965840094 , Updating Matrices Time 3.25488805771
# Centroid 74 : Taking candidates, Evaluating ED, Max ED: 0.105475314072 , Updating Matrices Time 3.26793885231
# Centroid 75 : Taking candidates, Evaluating ED, Max ED: 0.098461655152 , Updating Matrices Time 3.07004594803
# Centroid 76 : Taking candidates, Evaluating ED, Max ED: 0.0687082413587 , Updating Matrices Time 3.23391079903
# Centroid 77 : Taking candidates, Evaluating ED, Max ED: 0.0639464771625 , Updating Matrices Time 3.14972686768
# Centroid 78 : Taking candidates, Evaluating ED, Max ED: 0.0613577343981 , Updating Matrices Time 3.30355501175
# Centroid 79 : Taking candidates, Evaluating ED, Max ED: 0.0516986608184 , Updating Matrices Time 3.23376011848
# Centroid 80 : Taking candidates, Evaluating ED, Max ED: 0.0632171597276 , Updating Matrices Time 3.41086101532
# Centroid 81 : Taking candidates, Evaluating ED, Max ED: 0.120894277366 , Updating Matrices Time 3.15259003639
# Centroid 82 : Taking candidates, Evaluating ED, Max ED: 0.0607381459407 , Updating Matrices Time 3.29525113106
# Centroid 83 : Taking candidates, Evaluating ED, Max ED: 0.0431396750455 , Updating Matrices Time 3.23063111305
# Centroid 84 : Taking candidates, Evaluating ED, Max ED: 0.0602236630118 , Updating Matrices Time 3.26737618446
# Centroid 85 : Taking candidates, Evaluating ED, Max ED: 0.0720773457966 , Updating Matrices Time 3.39214587212
# Centroid 86 : Taking candidates, Evaluating ED, Max ED: 0.042281827916 , Updating Matrices Time 3.21797204018
# Centroid 87 : Taking candidates, Evaluating ED, Max ED: 0.0406723933696 , Updating Matrices Time 3.39052200317
# Centroid 88 : Taking candidates, Evaluating ED, Max ED: 0.0581082051362 , Updating Matrices Time 3.24283981323
# Centroid 89 : Taking candidates, Evaluating ED, Max ED: 0.0553577644505 , Updating Matrices Time 3.26294994354
# Centroid 90 : Taking candidates, Evaluating ED, Max ED: 0.0498641491991 , Updating Matrices Time 3.21736907959
# Centroid 91 : Taking candidates, Evaluating ED, Max ED: 0.0989261854272 , Updating Matrices Time 3.37218499184
# Centroid 92 : Taking candidates, Evaluating ED, Max ED: 0.0641567259745 , Updating Matrices Time 3.28468203545
# Centroid 93 : Taking candidates, Evaluating ED, Max ED: 0.105638383838 , Updating Matrices Time 3.35142707825
# Centroid 94 : Taking candidates, Evaluating ED, Max ED: 0.0450509812794 , Updating Matrices Time 3.4293680191
# Centroid 95 : Taking candidates, Evaluating ED, Max ED: 0.0664211500343 , Updating Matrices Time 3.28716611862
# Centroid 96 : Taking candidates, Evaluating ED, Max ED: 0.0616364542592 , Updating Matrices Time 3.25003194809
# Centroid 97 : Taking candidates, Evaluating ED, Max ED: 0.0417160225956 , Updating Matrices Time 3.4372959137
# Centroid 98 : Taking candidates, Evaluating ED, Max ED: 0.0330224920638 , Updating Matrices Time 3.38110208511
# Centroid 99 : Taking candidates, Evaluating ED, Max ED: 0.0553330935123 , Updating Matrices Time 3.41989421844
# Centroid 100 : Taking candidates, Evaluating ED, Max ED: 0.0544685156916 , Updating Matrices Time 3.3700261116
# Iteration 1 : DeltaW/W inf , Iteration Time 30.4371900558
# Iteration 2 : DeltaW/W 3.06191459497 , Iteration Time 35.6064639091
# Iteration 3 : DeltaW/W 0.361199531418 , Iteration Time 34.2044010162
# Iteration 4 : DeltaW/W 0.202946344037 , Iteration Time 30.401777029
# Iteration 5 : DeltaW/W 0.179844994268 , Iteration Time 31.8966550827
# Iteration 6 : DeltaW/W 0.128564054753 , Iteration Time 28.4863979816
# Iteration 7 : DeltaW/W 0.13451081003 , Iteration Time 30.5216009617
# Iteration 8 : DeltaW/W 0.106034840845 , Iteration Time 27.6147401333
# Iteration 9 : DeltaW/W 0.119757580899 , Iteration Time 27.1872878075
# Iteration 10 : DeltaW/W 0.117661639465 , Iteration Time 28.99335289
# Iteration 11 : DeltaW/W 0.0928030654648 , Iteration Time 26.6347270012
# Iteration 12 : DeltaW/W 0.0864831145641 , Iteration Time 28.3860599995
# Iteration 13 : DeltaW/W 0.0783894292947 , Iteration Time 29.8628780842
# Iteration 14 : DeltaW/W 0.0648628728192 , Iteration Time 26.6331079006
# Iteration 15 : DeltaW/W 0.0437818915126 , Iteration Time 27.3143532276
# Iteration 16 : DeltaW/W 0.0435131539718 , Iteration Time 26.7485361099
# Iteration 17 : DeltaW/W 0.0344128094701 , Iteration Time 27.3938369751
# Iteration 18 : DeltaW/W 0.0251462959417 , Iteration Time 27.9455749989
# Iteration 19 : DeltaW/W 0.0238994776169 , Iteration Time 28.4860379696
# Iteration 20 : DeltaW/W 0.0184343107312 , Iteration Time 29.4145359993
# Iteration 21 : DeltaW/W 0.0147464050595 , Iteration Time 26.2000310421
# Iteration 22 : DeltaW/W 0.0112328232109 , Iteration Time 28.3167808056
# Iteration 23 : DeltaW/W 0.00891081914822 , Iteration Time 25.4884459972
