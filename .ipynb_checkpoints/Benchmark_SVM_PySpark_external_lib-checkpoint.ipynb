# %% [markdown]
# # **Semiparametric SVM training using subgradients in Spark **
#
# #### bla, bla, bla.
#
# #### We will benchmark the algorithms with data files from UCI:
#
# * **Ripley**, the Ripley dataset
# * **Kwok**, the Kwok dataset
# * **Twonorm**, the Twonorm dataset
# * **Waveform**, the Waveform dataset
# * **Covertype**, the Covertype dataset

# %%
# definir variable de usuario y ejecutar condicionalmente cualquier código que dependa del contexto de ejecución
# no borrar código, simplemente ejecutarlo o no con un "if"
# cada uno mantiene actualizada su parte del "if" y no toca la del otro

#user = 'navia'
user = 'roberto'

#modelo = 'hybrid' 
#modelo = 'kernelgrad' 
overwrite_results = True # overwrites results even when the result file exists, skips the execution otherwise

if user == 'roberto':
    # definir sc
    import findspark
    findspark.init()
    from pyspark import SparkConf, SparkContext
    conf = (SparkConf().setMaster("local[4]").setAppName("My app").set("spark.executor.memory", "2g"))
    sc = SparkContext(conf = conf)
    import common.lib.svm_utils as SVM_UTILS
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    import pickle
    from pyspark.mllib.linalg import SparseVector, DenseVector
    from math import sqrt
    # %matplotlib inline
    # Se importan las funciones
    from pyspark.mllib.util import MLUtils
    from common.lib.IRWLSUtils import *
    Npartitions = 12
    Samplefraction = 0.05

if user == 'navia':
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/svm_utils.py")
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/IRWLSUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/KernelUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/ResultsUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/SGMAUtils.py")   
    import svm_utils as SVM_UTILS
    #from SGMAUtils import SGMA
    from IRWLSUtils import loadFile, train_SGMA_IRWLS, train_random_IRWLS, train_hybrid_SGMA_IRWLS, train_kmeans_IRWLS
    #from ResultsUtils import compute_AUCs
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    from pyspark.mllib.linalg import SparseVector, DenseVector
    import pickle
    from math import sqrt
    from pyspark.mllib.util import MLUtils
    # %matplotlib inline
    Npartitions = -99 # cuando es menor que 0, no se aplica y se deja libre
    Samplefraction = 0.05

# 0 = Ripley
# 1 = Kwok
# 2 = Twonorm
# 3 = Waveform
# 4 = Adult
# 5 = SUSY
# 6 = KddCup1999, requiere preprocesado...
# 7 = Higgs

datasets = [0, 1, 2, 3, 4, 5, 6]
folds = [0, 1, 2, 3, 4]
dataset_names = ['Ripley', 'Kwok', 'Twonorm', 'Waveform', 'Adult', 'Susy', 'KddCup1999', 'Higgs']
Niters = [50, 100, 200]
NCs = [5, 10, 25, 50, 100, 200]
modelos = ['hybridgrad', 'kernelgrad', 'SGMA_IRWLS', 'LinearSVM', 'Logistic', 'random_IRWLS', 'hybrid_IRWLS', 'Kmeans_IRWLS']

datasets = [4]
folds = [0]
modelos = ['hybrid_IRWLS']
Niters = [300]
NCs = [50]
Samplefraction = 0.05
IRWLS_stop_criteria=1e-3

for modelo in modelos:
    for kdataset in datasets:
        for kfold in folds:
            for Niter in Niters:
                C = 100.0
                name_dataset = dataset_names[kdataset]
                
                #####################################################################################################################
                # DATA LOADING: the result of this part must always be three RDDs for train, val and test, containing labelled points.
                #####################################################################################################################
                if kdataset in [0, 1, 2, 3]: # loading from .mat
                    x_tr, y_tr, x_val, y_val, x_tst, y_tst = SVM_UTILS.load_data(kdataset, kfold)
                    NI = x_tr.shape[1]
                    sigma = sqrt(NI)
                    
                    if Npartitions > 0:
                        XtrRDD = sc.parallelize(np.hstack((y_tr, x_tr)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XvalRDD = sc.parallelize(np.hstack((y_val, x_val)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XtstRDD = sc.parallelize(np.hstack((y_tst, x_tst)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                    else:
                        XtrRDD = sc.parallelize(np.hstack((y_tr, x_tr))).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XvalRDD = sc.parallelize(np.hstack((y_val, x_val))).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XtstRDD = sc.parallelize(np.hstack((y_tst, x_tst))).map(lambda x: LabeledPoint(x[0], x[1:]))
                       
                        
                if kdataset in [4]: # loading libsvm format
                    if kdataset == 4:
                        dimensions = 123                       
                    print "Loading " + name_dataset
                    XtrRDD = loadFile('./data/' + name_dataset.lower() + '_train',sc,dimensions,Npartitions)
                    XvalRDD = loadFile('./data/' + name_dataset.lower() + '_val',sc,dimensions,Npartitions)
                    XtstRDD = loadFile('./data/' + name_dataset.lower() + '_test',sc,dimensions,Npartitions)
                    sigma = np.sqrt(dimensions)
                    
                if kdataset in [5]: # loading in libsvm format and splitting RDD
                    if kdataset == 5:
                        filename = 'file:///export/usuarios01/navia/spark/SVM_spark/data/SUSY.txt'
                        if user == 'roberto':
                            filename = 'file:///home/operador/Documentos/AngelBigDataSVM/SVM_spark/data/SUSY.txt'
                        #filename = 'file:///export/usuarios01/navia/spark/SVM_spark/data/minisusy.txt'
                        dimensions = 18
                    rawdata = MLUtils.loadLibSVMFile(sc, filename)
                    # Labelled points are sparse, we map the values
                    rawdata = rawdata.map(lambda x: LabeledPoint(x.label, DenseVector((x.features).toArray())  ))
                    XtrRDD, XvalRDD, XtstRDD = rawdata.randomSplit(weights=[0.7, 0.1, 0.2], seed=1234)
                    sigma = np.sqrt(dimensions)               
                    XtrRDD.cache()
                    XvalRDD.cache()
                    XtstRDD.cache()
                #################################   END LOADING DATA ##########################################################
                
                for NC in NCs:
                    print "Dataset = %s, modelo = %s, kfold = %d, Niter = %d, NC = %d" % (name_dataset, modelo, kfold, Niter, NC)
                    filename = './results/dataset_' + str(kdataset) + '_modelo_' + modelo + '_NC_' + str(NC) + '_Niter_' + str(Niter) + '_kfold_' + str(kfold) + '.pkl'
                    #import code
                    #code.interact(local=locals())
                    try:
                        f = open(filename,'r')
                        f.close()
                        file_exists = True
                    except:
                        file_exists = False
                        pass
                    execute = False
                    if file_exists:
                        if overwrite_results:
                            execute = True
                    else:
                        execute = True                                  
                    if execute:

                        if modelo == 'hybridgrad':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_hybridSVM(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, Samplefraction)

                        if modelo == 'kernelgrad':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_kernelgrad(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, Samplefraction)

                        if modelo == 'SGMA_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria=IRWLS_stop_criteria)

                        if modelo == 'LinearSVM':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_linear_SVM(XtrRDD, XvalRDD, XtstRDD)
                                                
                        if modelo == 'Logistic':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_logistic(XtrRDD, XvalRDD, XtstRDD)

                        if modelo == 'random_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_random_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria=IRWLS_stop_criteria)

                        if modelo == 'hybrid_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_hybrid_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria=IRWLS_stop_criteria)

                        if modelo == 'Kmeans_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_kmeans_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria=IRWLS_stop_criteria)

                        print "Dataset = %s, modelo = %s, kfold = %d, Niter = %d, NC = %d" % (name_dataset, modelo, kfold, Niter, NC)
                        print "AUCtr = %f, AUCval = %f, AUCtst = %f" % (auc_tr, auc_val, auc_tst)
                        print "Elapsed minutes = %f" % (exe_time / 60.0)

                        with open(filename, 'w') as f:
                            pickle.dump([auc_tr, auc_val, auc_tst, exe_time], f)
# Out:
# Dataset = Susy, modelo = SGMA_IRWLS, kfold = 0, Niter = 300, NC = 20
# Mapping labels to (-1, 1)...
# Centroid 1 : Taking candidates, Evaluating ED, Max ED: 255.004934024 , Updating Matrices Time 16.3533139229
# Centroid 2 : Taking candidates, Evaluating ED, Max ED: 79.6607110297 , Updating Matrices Time 53.8111009598
# Centroid 3 : Taking candidates, Evaluating ED, Max ED: 28.1262083929 , Updating Matrices Time 54.4971289635
# Centroid 4 : Taking candidates, Evaluating ED, Max ED: 20.4017144308 , Updating Matrices Time 55.4461901188
# Centroid 5 : Taking candidates, Evaluating ED, Max ED: 14.7198121678 , Updating Matrices Time 57.5598678589
# Centroid 6 : Taking candidates, Evaluating ED, Max ED: 12.1169477826 , Updating Matrices Time 57.9513919353
# Centroid 7 : Taking candidates, Evaluating ED, Max ED: 8.22105167333 , Updating Matrices Time 62.8313770294
# Centroid 8 : Taking candidates, Evaluating ED, Max ED: 8.95891718773 , Updating Matrices Time 56.4799098969
# Centroid 9 : Taking candidates, Evaluating ED, Max ED: 6.61774128347 , Updating Matrices Time 66.498860836
# Centroid 10 : Taking candidates, Evaluating ED, Max ED: 9.68394663523 , Updating Matrices Time 61.6203608513
# Centroid 11 : Taking candidates, Evaluating ED, Max ED: 4.89044115827 , Updating Matrices Time 67.1642520428
# Centroid 12 : Taking candidates, Evaluating ED, Max ED: 5.88857042443 , Updating Matrices Time 61.8114209175
# Centroid 13 : Taking candidates, Evaluating ED, Max ED: 2.93852145853 , Updating Matrices Time 78.1233727932
# Centroid 14 : Taking candidates, Evaluating ED, Max ED: 4.26142412669 , Updating Matrices Time 64.6726920605
# Centroid 15 : Taking candidates, Evaluating ED, Max ED: 2.82087400807 , Updating Matrices Time 63.9644470215

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5d7dee05b281> in <module>()
#     152
#     153                         if modelo == 'SGMA_IRWLS':
# --> 154                             auc_tr, auc_val, auc_tst, exe_time = train_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria=IRWLS_stop_criteria)
#     155
#     156                         if modelo == 'LinearSVM':
#
# /home/operador/Documentos/gitPruebas/SVM_spark/common/lib/IRWLSUtils.pyc in train_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, stop_criteria)
#     181     Pesos = IRWLS(XtrRDD,Bases,C,sigma, stop_criteria=stop_criteria)
#     182
# --> 183     auc_tr, auc_val, auc_tst = compute_AUCs(XtrRDD, XvalRDD, XtstRDD, Bases,Pesos,sigma)
#     184
#     185     elapsed_time = time.time() - time_ini
#
# /home/operador/Documentos/gitPruebas/SVM_spark/common/lib/ResultsUtils.pyc in compute_AUCs(dataset_tr, dataset_val, dataset_tst, Bases, Pesos, sigma)
#      53     auc_tr = auc(fpr_tr, tpr_tr)
#      54
# ---> 55     LabelAndPredictions=np.array(dataset_val.map(lambda x:_labelAndPrediction(x,Bases,Pesos,sigma)).collect())
#      56     fpr_val, tpr_val, th_val = roc_curve(LabelAndPredictions[:,0], LabelAndPredictions[:,1])
#      57     auc_val = auc(fpr_val, tpr_val)
#
# /srv/spark/python/pyspark/rdd.pyc in collect(self)
#     769         """
#     770         with SCCallSiteSync(self.context) as css:
# --> 771             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     772         return list(_load_from_socket(port, self._jrdd_deserializer))
#     773
#
# /srv/spark/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     809             proto.END_COMMAND_PART
#     810
# --> 811         answer = self.gateway_client.send_command(command)
#     812         return_value = get_return_value(
#     813             answer, self.gateway_client, self.target_id, self.name)
#
# /srv/spark/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in send_command(self, command, retry)
#     624         connection = self._get_connection()
#     625         try:
# --> 626             response = connection.send_command(command)
#     627             self._give_back_connection(connection)
#     628         except Py4JNetworkError:
#
# /srv/spark/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in send_command(self, command)
#     738         try:
#     739             self.socket.sendall(command.encode("utf-8"))
# --> 740             answer = smart_decode(self.stream.readline()[:-1])
#     741             logger.debug("Answer received: {0}".format(answer))
#     742             # Happens when a the other end is dead. There might be an empty
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     428                     try:
#     429                         while data != "\n":
# --> 430                             data = recv(1)
#     431                             if not data:
#     432                                 break
#
# /srv/spark/python/pyspark/context.pyc in signal_handler(signal, frame)
#     223         def signal_handler(signal, frame):
#     224             self.cancelAllJobs()
# --> 225             raise KeyboardInterrupt()
#     226
#     227         # see http://stackoverflow.com/questions/23206787/
#
# KeyboardInterrupt:
