# %% [markdown]
# # **Semiparametric SVM training using subgradients in Spark **
#
# #### bla, bla, bla.
#
# #### We will benchmark the algorithms with data files from UCI:
#
# * **Ripley**, the Ripley dataset
# * **Kwok**, the Kwok dataset
# * **Twonorm**, the Twonorm dataset
# * **Waveform**, the Waveform dataset
# * **Covertype**, the Covertype dataset

# %%
# definir variable de usuario y ejecutar condicionalmente cualquier código que dependa del contexto de ejecución
# no borrar código, simplemente ejecutarlo o no con un "if"
# cada uno mantiene actualizada su parte del "if" y no toca la del otro

user = 'navia'
#user = 'roberto'

#modelo = 'hybrid' 
#modelo = 'kernelgrad' 
overwrite_results = True # overwrites results even when the result file exists, skips the execution otherwise

if user == 'roberto':
    # definir sc
    import findspark
    findspark.init()
    from pyspark import SparkConf, SparkContext
    conf = (SparkConf().setMaster("local[4]").setAppName("My app").set("spark.executor.memory", "2g"))
    sc = SparkContext(conf = conf)
    import common.lib.svm_utils as SVM_UTILS
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    import pickle
    from math import sqrt
    # %matplotlib inline
    # Se importan las funciones
    from pyspark.mllib.util import MLUtils
    from common.lib.IRWLSUtils import *
    Npartitions = 12
    Samplefraction = 0.05

if user == 'navia':
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/svm_utils.py")
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/IRWLSUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/KernelUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/ResultsUtils.py")   
    sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/SGMAUtils.py")   
    import svm_utils as SVM_UTILS
    #from SGMAUtils import SGMA
    from IRWLSUtils import loadFile, train_SGMA_IRWLS, train_random_IRWLS, train_hybrid_SGMA_IRWLS, train_kmeans_IRWLS
    #from ResultsUtils import compute_AUCs
    import numpy as np
    from pyspark.mllib.regression import LabeledPoint
    from pyspark.mllib.linalg import SparseVector, DenseVector
    import pickle
    from math import sqrt
    from pyspark.mllib.util import MLUtils
    # %matplotlib inline
    Npartitions = -99 # cuando es menor que 0, no se aplica y se deja libre
    Samplefraction = 0.05

# 0 = Ripley
# 1 = Kwok
# 2 = Twonorm
# 3 = Waveform
# 4 = Adult
# 5 = SUSY
# 6 = KddCup1999, requiere preprocesado...
# 7 = Higgs

datasets = [0, 1, 2, 3, 4, 5, 6]
folds = [0, 1, 2, 3, 4]
dataset_names = ['Ripley', 'Kwok', 'Twonorm', 'Waveform', 'Adult', 'Susy', 'KddCup1999', 'Higgs']
Niters = [50, 100, 200]
NCs = [5, 10, 25, 50, 100, 200]
modelos = ['hybridgrad', 'kernelgrad', 'SGMA_IRWLS', 'LinearSVM', 'Logistic', 'random_IRWLS', 'hybrid_IRWLS', 'Kmeans_IRWLS']

datasets = [5]
folds = [0]
modelos = ['SGMA_IRWLS']
Niters = [300]
NCs = [150]
Samplefraction = 0.05
fsigma = 0.9

for modelo in modelos:
    for kdataset in datasets:
        for kfold in folds:
            for Niter in Niters:
                C = 100.0
                name_dataset = dataset_names[kdataset]
                
                #####################################################################################################################
                # DATA LOADING: the result of this part must always be three RDDs for train, val and test, containing labelled points.
                #####################################################################################################################
                if kdataset in [0, 1, 2, 3]: # loading from .mat
                    x_tr, y_tr, x_val, y_val, x_tst, y_tst = SVM_UTILS.load_data(kdataset, kfold)
                    NI = x_tr.shape[1]
                    sigma = fsigma * sqrt(NI)
                    
                    if Npartitions > 0:
                        XtrRDD = sc.parallelize(np.hstack((y_tr, x_tr)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XvalRDD = sc.parallelize(np.hstack((y_val, x_val)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XtstRDD = sc.parallelize(np.hstack((y_tst, x_tst)), Npartitions).map(lambda x: LabeledPoint(x[0], x[1:]))
                    else:
                        XtrRDD = sc.parallelize(np.hstack((y_tr, x_tr))).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XvalRDD = sc.parallelize(np.hstack((y_val, x_val))).map(lambda x: LabeledPoint(x[0], x[1:]))
                        XtstRDD = sc.parallelize(np.hstack((y_tst, x_tst))).map(lambda x: LabeledPoint(x[0], x[1:]))
                       
                        
                if kdataset in [4]: # loading libsvm format
                    if kdataset == 4:
                        dimensions = 123                       
                    print "Loading " + name_dataset
                    XtrRDD = loadFile('./data/' + name_dataset.lower() + '_train',sc,dimensions,Npartitions)
                    XvalRDD = loadFile('./data/' + name_dataset.lower() + '_val',sc,dimensions,Npartitions)
                    XtstRDD = loadFile('./data/' + name_dataset.lower() + '_test',sc,dimensions,Npartitions)
                    sigma = fsigma * np.sqrt(dimensions)
                    
                if kdataset in [5]: # loading in libsvm format and splitting RDD
                    if kdataset == 5:
                        filename = 'file:///export/usuarios01/navia/spark/SVM_spark/data/SUSY.txt'
                        #filename = 'file:///export/usuarios01/navia/spark/SVM_spark/data/minisusy.txt'
                        dimensions = 18
                    rawdata = MLUtils.loadLibSVMFile(sc, filename)
                    # Labelled points are sparse, we map the values
                    rawdata = rawdata.map(lambda x: LabeledPoint(x.label, DenseVector((x.features).toArray())  ))
                    XtrRDD, XvalRDD, XtstRDD = rawdata.randomSplit(weights=[0.7, 0.1, 0.2], seed=1234)
                    sigma = fsigma * np.sqrt(dimensions)

                if kdataset in [7]: # loading as text, transforming to labelledpoint and splitting RDD into train, val and test
                    if kdataset == 7:
                        
                        filename = 'file:///export/g2pi/SPARK/data/higgs_tr.txt'
                        XtrRDD = sc.textFile(filename)
                        XtrRDD = XtrRDD.map(SVM_UTILS.text2labeled)

                        filename = 'file:///export/g2pi/SPARK/data/higgs_val.txt'
                        XvalRDD = sc.textFile(filename)
                        XvalRDD = XvalRDD.map(SVM_UTILS.text2labeled)
                                                
                        filename = 'file:///export/g2pi/SPARK/data/higgs_tst.txt'
                        XtstRDD = sc.textFile(filename)
                        XtstRDD = XtstRDD.map(SVM_UTILS.text2labeled)
                        sigma = fsigma * np.sqrt(len(XtstRDD.take(1)[0].features))

                        XtrRDD.cache()
                        XvalRDD.cache()
                        XtstRDD.cache()

                #################################   END LOADING DATA ##########################################################
                
                for NC in NCs:
                    print "Dataset = %s, modelo = %s, kfold = %d, Niter = %d, NC = %d" % (name_dataset, modelo, kfold, Niter, NC)
                    filename = './results/dataset_' + str(kdataset) + '_modelo_' + modelo + '_NC_' + str(NC) + '_Niter_' + str(Niter) + '_kfold_' + str(kfold) + '.pkl'
                    #import code
                    #code.interact(local=locals())
                    try:
                        f = open(filename,'r')
                        f.close()
                        file_exists = True
                    except:
                        file_exists = False
                        pass
                    execute = False
                    if file_exists:
                        if overwrite_results:
                            execute = True
                    else:
                        execute = True                                  
                    if execute:

                        if modelo == 'hybridgrad':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_hybridSVM(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, Samplefraction)

                        if modelo == 'kernelgrad':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_kernelgrad(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter, Samplefraction)

                        if modelo == 'SGMA_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter)

                        if modelo == 'LinearSVM':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_linear_SVM(XtrRDD, XvalRDD, XtstRDD)
                                                
                        if modelo == 'Logistic':
                            auc_tr, auc_val, auc_tst, exe_time = SVM_UTILS.train_logistic(XtrRDD, XvalRDD, XtstRDD)

                        if modelo == 'random_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_random_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter)

                        if modelo == 'hybrid_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_hybrid_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter)

                        if modelo == 'Kmeans_IRWLS':
                            auc_tr, auc_val, auc_tst, exe_time = train_kmeans_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter)

                        print "Dataset = %s, modelo = %s, kfold = %d, Niter = %d, NC = %d" % (name_dataset, modelo, kfold, Niter, NC)
                        print "AUCtr = %f, AUCval = %f, AUCtst = %f" % (auc_tr, auc_val, auc_tst)
                        print "Elapsed minutes = %f" % (exe_time / 60.0)

                        with open(filename, 'w') as f:
                            pickle.dump([auc_tr, auc_val, auc_tst, exe_time], f)
# Out:
# Dataset = Susy, modelo = SGMA_IRWLS, kfold = 0, Niter = 300, NC = 100
# Mapping labels to (-1, 1)...
# Centroid 1 : Taking candidates, Evaluating ED, Max ED: 239.83461447 , Updating Matrices Time 20.756857872
# Centroid 2 : Taking candidates, Evaluating ED, Max ED: 101.642079527 , Updating Matrices Time 24.6420760155
# Centroid 3 : Taking candidates, Evaluating ED, Max ED: 52.1546220803 , Updating Matrices Time 26.5730988979
# Centroid 4 : Taking candidates, Evaluating ED, Max ED: 41.1717053551 , Updating Matrices Time 27.5907771587
# Centroid 5 : Taking candidates, Evaluating ED, Max ED: 37.6192446201 , Updating Matrices Time 30.110959053
# Centroid 6 : Taking candidates, Evaluating ED, Max ED: 33.1620680763 , Updating Matrices Time 31.3458719254
# Centroid 7 : Taking candidates, Evaluating ED, Max ED: 24.583930032 , Updating Matrices Time 32.7942018509
# Centroid 8 : Taking candidates, Evaluating ED, Max ED: 33.0706859391 , Updating Matrices Time 38.3489830494
# Centroid 9 : Taking candidates, Evaluating ED, Max ED: 42.8085462277 , Updating Matrices Time 36.4946701527
# Centroid 10 : Taking candidates, Evaluating ED, Max ED: 28.4221133396 , Updating Matrices Time 42.945579052
# Centroid 11 : Taking candidates, Evaluating ED, Max ED: 24.2097470921 , Updating Matrices Time 39.1405820847
# Centroid 12 : Taking candidates, Evaluating ED, Max ED: 29.6629197647 , Updating Matrices Time 40.985916853
# Centroid 13 : Taking candidates, Evaluating ED, Max ED: 25.7911977239 , Updating Matrices Time 42.5714890957
# Centroid 14 : Taking candidates, Evaluating ED, Max ED: 28.8160068813 , Updating Matrices Time 44.0423491001
# Centroid 15 : Taking candidates, Evaluating ED, Max ED: 27.9175877079 , Updating Matrices Time 45.9933121204
# Centroid 16 : Taking candidates, Evaluating ED, Max ED: 22.6344637827 , Updating Matrices Time 47.3554918766
# Centroid 17 : Taking candidates, Evaluating ED, Max ED: 27.842251725 , Updating Matrices Time 48.9216749668
# Centroid 18 : Taking candidates, Evaluating ED, Max ED: 19.4945442612 , Updating Matrices Time 50.8040189743
# Centroid 19 : Taking candidates, Evaluating ED, Max ED: 29.8048840297 , Updating Matrices Time 52.1679320335
# Centroid 20 : Taking candidates, Evaluating ED, Max ED: 19.6877515142 , Updating Matrices Time 53.9196808338
# Centroid 21 : Taking candidates, Evaluating ED, Max ED: 20.6849787846 , Updating Matrices Time 55.5934510231
# Centroid 22 : Taking candidates, Evaluating ED, Max ED: 21.7820455004 , Updating Matrices Time 56.9066097736
# Centroid 23 : Taking candidates, Evaluating ED, Max ED: 18.56877963 , Updating Matrices Time 58.7284839153
# Centroid 24 : Taking candidates, Evaluating ED, Max ED: 23.4568822266 , Updating Matrices Time 60.3388829231
# Centroid 25 : Taking candidates, Evaluating ED, Max ED: 22.7216358047 , Updating Matrices Time 61.9882321358
# Centroid 26 : Taking candidates, Evaluating ED, Max ED: 23.6303978129 , Updating Matrices Time 63.9411199093
# Centroid 27 : Taking candidates, Evaluating ED, Max ED: 28.9501853966 , Updating Matrices Time 65.4955120087
# Centroid 28 : Taking candidates, Evaluating ED, Max ED: 22.6185587953 , Updating Matrices Time 67.0561301708
# Centroid 29 : Taking candidates, Evaluating ED, Max ED: 45.4071565908 , Updating Matrices Time 68.4738080502
# Centroid 30 : Taking candidates, Evaluating ED, Max ED: 16.7889507484 , Updating Matrices Time 70.5958988667
# Centroid 31 : Taking candidates, Evaluating ED, Max ED: 19.7774382018 , Updating Matrices Time 72.0056738853
# Centroid 32 : Taking candidates, Evaluating ED, Max ED: 28.4674079118 , Updating Matrices Time 73.9419140816
# Centroid 33 : Taking candidates, Evaluating ED, Max ED: 28.7822284179 , Updating Matrices Time 75.3058218956
# Centroid 34 : Taking candidates, Evaluating ED, Max ED: 31.2918690229 , Updating Matrices Time 76.7670810223
# Centroid 35 : Taking candidates, Evaluating ED, Max ED: 30.0165645422 , Updating Matrices Time 78.8773589134
# Centroid 36 : Taking candidates, Evaluating ED, Max ED: 22.2835002856 , Updating Matrices Time 80.773665905
# Centroid 37 : Taking candidates, Evaluating ED, Max ED: 42.8331786733 , Updating Matrices Time 81.6345210075
# Centroid 38 : Taking candidates, Evaluating ED, Max ED: 48.5815849008 , Updating Matrices Time 83.0359461308
# Centroid 39 : Taking candidates, Evaluating ED, Max ED: 25.3885853582 , Updating Matrices Time 84.9164719582
# Centroid 40 : Taking candidates, Evaluating ED, Max ED: 36.3238778137 , Updating Matrices Time 86.6906762123
# Centroid 41 : Taking candidates, Evaluating ED, Max ED: 22.296261768 , Updating Matrices Time 88.1650002003
# Centroid 42 : Taking candidates, Evaluating ED, Max ED: 25.9448451636 , Updating Matrices Time 89.5726401806
# Centroid 43 : Taking candidates, Evaluating ED, Max ED: 20.874781344 , Updating Matrices Time 90.6233990192
# Centroid 44 : Taking candidates, Evaluating ED, Max ED: 23.7601474065 , Updating Matrices Time 92.6795639992
# Centroid 45 : Taking candidates, Evaluating ED, Max ED: 22.9369914802 , Updating Matrices Time 94.0610749722
# Centroid 46 : Taking candidates, Evaluating ED, Max ED: 28.2836834415 , Updating Matrices Time 95.6223130226
# Centroid 47 : Taking candidates, Evaluating ED, Max ED: 19.2254856019 , Updating Matrices Time 96.8475248814
# Centroid 48 : Taking candidates, Evaluating ED, Max ED: 40.3019060308 , Updating Matrices Time 98.5211980343
# Centroid 49 : Taking candidates, Evaluating ED, Max ED: 33.794928546 , Updating Matrices Time 100.398380041
# Centroid 50 : Taking candidates, Evaluating ED, Max ED: 24.1907389864 , Updating Matrices Time 101.889625072
# Centroid 51 : Taking candidates, Evaluating ED, Max ED: 38.7001851571 , Updating Matrices Time 103.695973158
# Centroid 52 : Taking candidates, Evaluating ED, Max ED: 47.5274191807 , Updating Matrices Time 106.146589994
# Centroid 53 : Taking candidates, Evaluating ED, Max ED: 43.26769302 , Updating Matrices Time 107.5458951
# Centroid 54 : Taking candidates, Evaluating ED, Max ED: 28.0329792738 , Updating Matrices Time 109.135564804
# Centroid 55 : Taking candidates, Evaluating ED, Max ED: 28.2295851004 , Updating Matrices Time 110.385123968
# Centroid 56 : Taking candidates, Evaluating ED, Max ED: 38.054267514 , Updating Matrices Time 111.754150152
# Centroid 57 : Taking candidates, Evaluating ED, Max ED: 47.7800073856 , Updating Matrices Time 113.723975897
# Centroid 58 : Taking candidates, Evaluating ED, Max ED: 27.4670247206 , Updating Matrices Time 115.436964035
# Centroid 59 : Taking candidates, Evaluating ED, Max ED: 25.1140202763 , Updating Matrices Time 117.301913977
# Centroid 60 : Taking candidates, Evaluating ED, Max ED: 23.010443134 , Updating Matrices Time 118.896721125
# Centroid 61 : Taking candidates, Evaluating ED, Max ED: 23.7128357179 , Updating Matrices Time 120.407757998
# Centroid 62 : Taking candidates, Evaluating ED, Max ED: 47.171780668 , Updating Matrices Time 121.596304893
# Centroid 63 : Taking candidates, Evaluating ED, Max ED: 26.3702681608 , Updating Matrices Time 123.320563793
# Centroid 64 : Taking candidates, Evaluating ED, Max ED: 20.8981121894 , Updating Matrices Time 125.146569967
# Centroid 65 : Taking candidates, Evaluating ED, Max ED: 29.3280794394 , Updating Matrices Time 126.700581074
# Centroid 66 : Taking candidates, Evaluating ED, Max ED: 29.5860934308 , Updating Matrices Time 128.638946056
# Centroid 67 : Taking candidates, Evaluating ED, Max ED: 14.1408737285 , Updating Matrices Time 130.288870096
# Centroid 68 : Taking candidates, Evaluating ED, Max ED: 30.4156631827 , Updating Matrices Time 131.31345892
# Centroid 69 : Taking candidates, Evaluating ED, Max ED: 55.9915784295 , Updating Matrices Time 132.690832138
# Centroid 70 : Taking candidates, Evaluating ED, Max ED: 21.0456650449 , Updating Matrices Time 134.286442041
# Centroid 71 : Taking candidates, Evaluating ED, Max ED: 35.7535231255 , Updating Matrices Time 136.054631948
# Centroid 72 : Taking candidates, Evaluating ED, Max ED: 39.9807736042 , Updating Matrices Time 137.785850048
# Centroid 73 : Taking candidates, Evaluating ED, Max ED: 34.981280581 , Updating Matrices Time 139.84561801
# Centroid 74 : Taking candidates, Evaluating ED, Max ED: 28.9954483345 , Updating Matrices Time 141.15058589
# Centroid 75 : Taking candidates, Evaluating ED, Max ED: 22.4737938547 , Updating Matrices Time 142.855458975
# Centroid 76 : Taking candidates, Evaluating ED, Max ED: 19.8782377043 , Updating Matrices Time 133.271670103
# Centroid 77 : Taking candidates, Evaluating ED, Max ED: 19.013124322 , Updating Matrices Time 131.082099915
# Centroid 78 : Taking candidates, Evaluating ED, Max ED: 33.8124801205 , Updating Matrices Time 175.576673031
# Centroid 79 : Taking candidates, Evaluating ED, Max ED: 22.9507232759 , Updating Matrices Time 136.684953928
# Centroid 80 : Taking candidates, Evaluating ED, Max ED: 60.8331510745 , Updating Matrices Time 136.582611084
# Centroid 81 : Taking candidates, Evaluating ED, Max ED: 23.3127058138 , Updating Matrices Time 138.033314943
# Centroid 82 : Taking candidates, Evaluating ED, Max ED: 31.6331478401 , Updating Matrices Time 141.357106924
# Centroid 83 : Taking candidates, Evaluating ED, Max ED: 24.0539251297 , Updating Matrices Time 144.583369017
# Centroid 84 : Taking candidates, Evaluating ED, Max ED: 20.5180040908 , Updating Matrices Time 157.790614128
# Centroid 85 : Taking candidates, Evaluating ED, Max ED: 20.9301210046 , Updating Matrices Time 146.802700996
# Centroid 86 : Taking candidates, Evaluating ED, Max ED: 36.1980785273 , Updating Matrices Time 147.844281197
# Centroid 87 : Taking candidates, Evaluating ED, Max ED: 31.3611588177 , Updating Matrices Time 163.453131914
# Centroid 88 : Taking candidates, Evaluating ED, Max ED: 26.4687731268 , Updating Matrices Time 163.951898098
# Centroid 89 : Taking candidates, Evaluating ED, Max ED: 24.9809195743 , Updating Matrices Time 148.369554996
# Centroid 90 : Taking candidates, Evaluating ED, Max ED: 22.7318272023 , Updating Matrices Time 152.889765978
# Centroid 91 : Taking candidates, Evaluating ED, Max ED: 36.437557196 , Updating Matrices Time 155.541784048
# Centroid 92 : Taking candidates, Evaluating ED, Max ED: 12.8161138147 , Updating Matrices Time 157.949056864
# Centroid 93 : Taking candidates, Evaluating ED, Max ED: 31.1278783295 , Updating Matrices Time 156.360349178
# Centroid 94 : Taking candidates, Evaluating ED, Max ED: 39.1650994052 , Updating Matrices Time 159.624042988
# Centroid 95 : Taking candidates, Evaluating ED, Max ED: 21.3851634263 , Updating Matrices Time 161.275876999
# Centroid 96 : Taking candidates, Evaluating ED, Max ED: 53.2328352206 , Updating Matrices Time 162.233733177
# Centroid 97 : Taking candidates, Evaluating ED, Max ED: 39.8851621012 , Updating Matrices Time 163.587173939
# Centroid 98 : Taking candidates, Evaluating ED, Max ED: 58.9448872474 , Updating Matrices Time 169.314019203
# Centroid 99 : Taking candidates, Evaluating ED, Max ED: 24.4987324229 , Updating Matrices Time 162.569843054
