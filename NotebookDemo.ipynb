# %% [markdown]
# # **Semiparametric SVM training in Spark **
#
# This is an example to run the code used in the paper:
#
# "Distributed Non-Linear Semiparametric Support Vector Machine for Big Data Applications on Spark"
#
# Submitted to the journal:
#
# "IEEE Transactions on Systems, Man and Cybernetics: Systems"
#
# This library can be used to train a Distributed Semiparametric SVM:
#
#  - Making use of a distributed and stochastic version of the Sparse Greedy Matrix Approximation algorithm (called DSSGMA) to obtain the elements of the semiparametric model.
#  - Using a distributed version of the Iterative Re-Weighted Least Squares procedure to obtain the weights of the semiparametric model.
#
# Concretely this example run the algorithm on the adult dataset.

# %%
##############################
# Some jupyter notebook for are preconfigured to run diretly over pyspark
# 
# An alternative is the installation of findspark and running the notebook from python.
# If your have installed findspark uncomment the following lines and change the spark configuration
# to point directly to your spark 
##############################

#import findspark
#findspark.init()
#from pyspark import SparkConf, SparkContext
#conf = (SparkConf().setMaster("local[4]").setAppName("My app").set("spark.executor.memory", "2g"))
#sc = SparkContext(conf = conf)


# %matplotlib inline
from math import sqrt
from common.lib.IRWLSUtils import *
from pyspark.mllib.util import MLUtils
import numpy as np
from pyspark.mllib.regression import LabeledPoint
    

#sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/svm_utils.py")
#sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/IRWLSUtils.py")   
#sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/KernelUtils.py")   
#sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/ResultsUtils.py")   
#sc.addPyFile("file:///export/usuarios01/navia/spark/SVM_spark/common/lib/SGMAUtils.py")   
#from IRWLSUtils import loadFile, train_SGMA_IRWLS

    

# Initialization of hte variables         
Npartitions = -99 # The number of partitions in the RDD, using a negative value the cluster choose the number.
Samplefraction = 0.05
Niter = 300
NC = 50
C=100.0


print "Loading Adult dataset"
dimensions = 123                           
XtrRDD = loadFile('./data/' + 'adult_train',sc,dimensions,Npartitions)
XvalRDD = loadFile('./data/' + 'adult_val',sc,dimensions,Npartitions)
XtstRDD = loadFile('./data/' + 'adult_test',sc,dimensions,Npartitions)

fsigma = 0.9
sigma = fsigma * np.sqrt(dimensions)
                    

XtrRDD.cache()
XvalRDD.cache()
XtstRDD.cache()

             
auc_tr, auc_val, auc_tst, exe_time = train_SGMA_IRWLS(XtrRDD, XvalRDD, XtstRDD, sigma, C, NC, Niter)


print "AUCtr = %f, AUCval = %f, AUCtst = %f" % (auc_tr, auc_val, auc_tst)
print "Elapsed minutes = %f" % (exe_time / 60.0)
# Out:
# Loading Adult dataset
# Centroid 1 : Taking candidates, Evaluating ED, Max ED: 781.670223008 , Updating Matrices Time 1.49642109871
# Centroid 2 : Taking candidates, Evaluating ED, Max ED: 6.8187263131 , Updating Matrices Time 2.70972108841
# Centroid 3 : Taking candidates, Evaluating ED, Max ED: 0.945041056222 , Updating Matrices Time 2.56803417206
# Centroid 4 : Taking candidates, Evaluating ED, Max ED: 0.708839871664 , Updating Matrices Time 2.18658208847
# Centroid 5 : Taking candidates, Evaluating ED, Max ED: 0.3276716505 , Updating Matrices Time 2.41872906685
# Centroid 6 : Taking candidates, Evaluating ED, Max ED: 0.150301087224 , Updating Matrices Time 2.38541007042
# Centroid 7 : Taking candidates, Evaluating ED, Max ED: 0.166837828351 , Updating Matrices Time 2.48313903809
# Centroid 8 : Taking candidates, Evaluating ED, Max ED: 0.135551089682 , Updating Matrices Time 2.26849293709
# Centroid 9 : Taking candidates, Evaluating ED, Max ED: 0.169826778195 , Updating Matrices Time 2.5240521431
# Centroid 10 : Taking candidates, Evaluating ED, Max ED: 0.120783966274 , Updating Matrices Time 2.10725307465
# Centroid 11 : Taking candidates, Evaluating ED, Max ED: 0.0995011792632 , Updating Matrices Time 2.38162398338
# Centroid 12 : Taking candidates, Evaluating ED, Max ED: 0.0799106050122 , Updating Matrices Time 2.33083200455
# Centroid 13 : Taking candidates, Evaluating ED, Max ED: 0.0773882721023 , Updating Matrices Time 2.41370916367
# Centroid 14 : Taking candidates, Evaluating ED, Max ED: 0.0750255308622 , Updating Matrices Time 2.63242292404
# Centroid 15 : Taking candidates, Evaluating ED, Max ED: 0.0680363759512 , Updating Matrices Time 2.48416399956
# Centroid 16 : Taking candidates, Evaluating ED, Max ED: 0.0438120065363 , Updating Matrices Time 2.49092006683
# Centroid 17 : Taking candidates, Evaluating ED, Max ED: 0.045057712715 , Updating Matrices Time 2.36395215988
# Centroid 18 : Taking candidates, Evaluating ED, Max ED: 0.0328205968701 , Updating Matrices Time 2.37059807777
# Centroid 19 : Taking candidates, Evaluating ED, Max ED: 0.0393388389994 , Updating Matrices Time 2.30247092247
# Centroid 20 : Taking candidates, Evaluating ED, Max ED: 0.0470839164224 , Updating Matrices Time 2.47139620781
# Centroid 21 : Taking candidates, Evaluating ED, Max ED: 0.0359094387935 , Updating Matrices Time 2.39639806747
# Centroid 22 : Taking candidates, Evaluating ED, Max ED: 0.0309122466249 , Updating Matrices Time 2.54061794281
# Centroid 23 : Taking candidates, Evaluating ED, Max ED: 0.0291849235431 , Updating Matrices Time 2.37410402298
# Centroid 24 : Taking candidates, Evaluating ED, Max ED: 0.0259783739428 , Updating Matrices Time 2.16389799118
# Centroid 25 : Taking candidates, Evaluating ED, Max ED: 0.0258075386862 , Updating Matrices Time 2.42707300186
# Centroid 26 : Taking candidates, Evaluating ED, Max ED: 0.0239642676008 , Updating Matrices Time 2.40832495689
# Centroid 27 : Taking candidates, Evaluating ED, Max ED: 0.0412093260537 , Updating Matrices Time 2.34641218185
# Centroid 28 : Taking candidates, Evaluating ED, Max ED: 0.0246612468974 , Updating Matrices Time 2.32908892632
# Centroid 29 : Taking candidates, Evaluating ED, Max ED: 0.0132868002346 , Updating Matrices Time 2.30793499947
# Centroid 30 : Taking candidates, Evaluating ED, Max ED: 0.019730557138 , Updating Matrices Time 2.41667604446
# Centroid 31 : Taking candidates, Evaluating ED, Max ED: 0.0115935809841 , Updating Matrices Time 2.47643208504
# Centroid 32 : Taking candidates, Evaluating ED, Max ED: 0.0149858500728 , Updating Matrices Time 2.55049705505
# Centroid 33 : Taking candidates, Evaluating ED, Max ED: 0.0188517364288 , Updating Matrices Time 2.29935097694
# Centroid 34 : Taking candidates, Evaluating ED, Max ED: 0.0153303096828 , Updating Matrices Time 2.49058389664
# Centroid 35 : Taking candidates, Evaluating ED, Max ED: 0.0104328821705 , Updating Matrices Time 2.37738800049
# Centroid 36 : Taking candidates, Evaluating ED, Max ED: 0.011474293506 , Updating Matrices Time 2.3311920166
# Centroid 37 : Taking candidates, Evaluating ED, Max ED: 0.0140837330959 , Updating Matrices Time 2.50416088104
# Centroid 38 : Taking candidates, Evaluating ED, Max ED: 0.00739831159508 , Updating Matrices Time 2.28362894058
# Centroid 39 : Taking candidates, Evaluating ED, Max ED: 0.00914914159526 , Updating Matrices Time 2.47603988647
# Centroid 40 : Taking candidates, Evaluating ED, Max ED: 0.017678139953 , Updating Matrices Time 2.41633319855
# Centroid 41 : Taking candidates, Evaluating ED, Max ED: 0.00755427290112 , Updating Matrices Time 2.29702305794
# Centroid 42 : Taking candidates, Evaluating ED, Max ED: 0.00607178034098 , Updating Matrices Time 2.37222290039
# Centroid 43 : Taking candidates, Evaluating ED, Max ED: 0.00622778364441 , Updating Matrices Time 2.60867500305
# Centroid 44 : Taking candidates, Evaluating ED, Max ED: 0.00467841484739 , Updating Matrices Time 2.37729811668
# Centroid 45 : Taking candidates, Evaluating ED, Max ED: 0.00420089080637 , Updating Matrices Time 2.44483780861
# Centroid 46 : Taking candidates, Evaluating ED, Max ED: 0.00398189225323 , Updating Matrices Time 2.37492895126
# Centroid 47 : Taking candidates, Evaluating ED, Max ED: 0.00570643131538 , Updating Matrices Time 2.41420793533
# Centroid 48 : Taking candidates, Evaluating ED, Max ED: 0.0037388291588 , Updating Matrices Time 2.3487830162
# Centroid 49 : Taking candidates, Evaluating ED, Max ED: 0.00424569098168 , Updating Matrices Time 2.38920211792
# Centroid 50 : Taking candidates, Evaluating ED, Max ED: 0.00224636496458 , Updating Matrices Time 2.25839090347
# Iteration 1 : DeltaW/W inf , Iteration Time 0.871537923813
# Iteration 2 : DeltaW/W 0.320756336318 , Iteration Time 0.550140142441
# Iteration 3 : DeltaW/W 0.202794260676 , Iteration Time 0.541545152664
# Iteration 4 : DeltaW/W 0.200795101246 , Iteration Time 0.529169082642
# Iteration 5 : DeltaW/W 0.164224679234 , Iteration Time 0.536263942719
# Iteration 6 : DeltaW/W 0.153327018433 , Iteration Time 0.488836050034
# Iteration 7 : DeltaW/W 0.112199996694 , Iteration Time 0.498004198074
# Iteration 8 : DeltaW/W 0.099057704397 , Iteration Time 0.47632598877
# Iteration 9 : DeltaW/W 0.11200452873 , Iteration Time 0.512321949005
# Iteration 10 : DeltaW/W 0.0844370208281 , Iteration Time 0.499933004379
# Iteration 11 : DeltaW/W 0.0773249540365 , Iteration Time 0.475028038025
# Iteration 12 : DeltaW/W 0.0591593071926 , Iteration Time 0.463800907135
# Iteration 13 : DeltaW/W 0.0448273294045 , Iteration Time 0.478294849396
# Iteration 14 : DeltaW/W 0.0377120645554 , Iteration Time 0.452607154846
# Iteration 15 : DeltaW/W 0.0330629861626 , Iteration Time 0.43060708046
# Iteration 16 : DeltaW/W 0.0244624141188 , Iteration Time 0.473387002945
# Iteration 17 : DeltaW/W 0.0226196143276 , Iteration Time 0.456892967224
# Iteration 18 : DeltaW/W 0.0174801433813 , Iteration Time 0.456382989883
# Iteration 19 : DeltaW/W 0.0175315646107 , Iteration Time 0.405619859695
# Iteration 20 : DeltaW/W 0.0161888269269 , Iteration Time 0.487331867218
# Iteration 21 : DeltaW/W 0.0123425648776 , Iteration Time 0.427446126938
# Iteration 22 : DeltaW/W 0.00873853807622 , Iteration Time 0.365040063858
# Iteration 23 : DeltaW/W 0.00853513197818 , Iteration Time 0.434001922607
# Iteration 24 : DeltaW/W 0.00614321474971 , Iteration Time 0.47641992569
# Iteration 25 : DeltaW/W 0.00478113972651 , Iteration Time 0.445287942886
# Iteration 26 : DeltaW/W 0.0043836385052 , Iteration Time 0.445677995682
# Iteration 27 : DeltaW/W 0.00312730134148 , Iteration Time 0.414265871048
# Iteration 28 : DeltaW/W 0.00249147976568 , Iteration Time 0.454985141754
# Iteration 29 : DeltaW/W 0.00207240256117 , Iteration Time 0.416155099869
# Iteration 30 : DeltaW/W 0.0017679357538 , Iteration Time 0.436238050461
# Iteration 31 : DeltaW/W 0.0014652635189 , Iteration Time 0.484709978104
# Iteration 32 : DeltaW/W 0.00119207520865 , Iteration Time 0.446776151657
# AUCtr = 0.898452, AUCval = 0.896680, AUCtst = 0.896680
# Elapsed minutes = 2.982433
